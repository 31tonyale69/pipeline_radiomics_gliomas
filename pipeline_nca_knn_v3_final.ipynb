# %% [markdown]
# ### Pipeline : KNN and Dimensionality Reduction with NCA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap
import seaborn as sns
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedStratifiedKFold
from sklearn.neighbors import KNeighborsClassifier, NeighborhoodComponentsAnalysis
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix, precision_score
from sklearn.metrics import precision_recall_curve, f1_score, auc, average_precision_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn import metrics
from collections import Counter
from sklearn.neighbors import LocalOutlierFactor

# %% [markdown]
# ### Load Data and Check Shape

# %%
data = pd.read_csv("train_159_text.csv")
print(data.shape)
# Out:
# (159, 69)

# %%
x=data.drop('saidas', axis=1)
y=data['saidas']
print(x.shape)
print(y.shape)
# Out:
# (159, 68)
# (159,)

# %%
counter = Counter(y)
print(counter)
# Out:
# Counter({1.0: 102, 0.0: 57})

# %% [markdown]
# ### Step 1 - Results with KNN

# %%
for i in range(1,31):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, shuffle=True)
    knn = KNeighborsClassifier(n_neighbors = 1)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)
    aucroc = roc_auc_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, digits=4)

    print("Basic KNN Accuracy: {:.2f}".format(acc*100))
    print("Valor AUC-ROC : {:.2f}".format(aucroc*100))
    print("CM : \n", cm)
    print(report)
    
    trueNegative=cm[0][0]
    falsePositive=cm[0][1]
    falsenegative=cm[1][0]
    truePositive=cm[1][1]
  
    print("Sensibilidade: {:.2f}".format((truePositive/(truePositive+falsenegative))*100))
    print("Especificidade: {:.2f}".format((trueNegative/(trueNegative+falsePositive))*100))
    print()
# Out:
# Basic KNN Accuracy: 31.25
# Valor AUC-ROC : 34.13
# CM :
#  [[1 8]
#  [3 4]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.1111    0.1538         9
#          1.0     0.3333    0.5714    0.4211         7
#
#     accuracy                         0.3125        16
#    macro avg     0.2917    0.3413    0.2874        16
# weighted avg     0.2865    0.3125    0.2707        16
#
# Sensibilidade: 57.14
# Especificidade: 11.11
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 55.00
# CM :
#  [[3 3]
#  [4 6]]
#               precision    recall  f1-score   support
#
#          0.0     0.4286    0.5000    0.4615         6
#          1.0     0.6667    0.6000    0.6316        10
#
#     accuracy                         0.5625        16
#    macro avg     0.5476    0.5500    0.5466        16
# weighted avg     0.5774    0.5625    0.5678        16
#
# Sensibilidade: 60.00
# Especificidade: 50.00
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 71.43
# CM :
#  [[3 4]
#  [0 9]]
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.4286    0.6000         7
#          1.0     0.6923    1.0000    0.8182         9
#
#     accuracy                         0.7500        16
#    macro avg     0.8462    0.7143    0.7091        16
# weighted avg     0.8269    0.7500    0.7227        16
#
# Sensibilidade: 100.00
# Especificidade: 42.86
#
# Basic KNN Accuracy: 81.25
# Valor AUC-ROC : 78.33
# CM :
#  [[4 2]
#  [1 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.8000    0.6667    0.7273         6
#          1.0     0.8182    0.9000    0.8571        10
#
#     accuracy                         0.8125        16
#    macro avg     0.8091    0.7833    0.7922        16
# weighted avg     0.8114    0.8125    0.8084        16
#
# Sensibilidade: 90.00
# Especificidade: 66.67
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 51.28
# CM :
#  [[1 2]
#  [4 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.2000    0.3333    0.2500         3
#          1.0     0.8182    0.6923    0.7500        13
#
#     accuracy                         0.6250        16
#    macro avg     0.5091    0.5128    0.5000        16
# weighted avg     0.7023    0.6250    0.6563        16
#
# Sensibilidade: 69.23
# Especificidade: 33.33
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 61.90
# CM :
#  [[4 3]
#  [3 6]]
#               precision    recall  f1-score   support
#
#          0.0     0.5714    0.5714    0.5714         7
#          1.0     0.6667    0.6667    0.6667         9
#
#     accuracy                         0.6250        16
#    macro avg     0.6190    0.6190    0.6190        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# Sensibilidade: 66.67
# Especificidade: 57.14
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 64.29
# CM :
#  [[2 5]
#  [0 9]]
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.2857    0.4444         7
#          1.0     0.6429    1.0000    0.7826         9
#
#     accuracy                         0.6875        16
#    macro avg     0.8214    0.6429    0.6135        16
# weighted avg     0.7991    0.6875    0.6347        16
#
# Sensibilidade: 100.00
# Especificidade: 28.57
#
# Basic KNN Accuracy: 50.00
# Valor AUC-ROC : 52.73
# CM :
#  [[3 2]
#  [6 5]]
#               precision    recall  f1-score   support
#
#          0.0     0.3333    0.6000    0.4286         5
#          1.0     0.7143    0.4545    0.5556        11
#
#     accuracy                         0.5000        16
#    macro avg     0.5238    0.5273    0.4921        16
# weighted avg     0.5952    0.5000    0.5159        16
#
# Sensibilidade: 45.45
# Especificidade: 60.00
#
# Basic KNN Accuracy: 81.25
# Valor AUC-ROC : 75.45
# CM :
#  [[ 3  2]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.6000    0.6667         5
#          1.0     0.8333    0.9091    0.8696        11
#
#     accuracy                         0.8125        16
#    macro avg     0.7917    0.7545    0.7681        16
# weighted avg     0.8073    0.8125    0.8062        16
#
# Sensibilidade: 90.91
# Especificidade: 60.00
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 53.17
# CM :
#  [[2 5]
#  [2 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.2857    0.3636         7
#          1.0     0.5833    0.7778    0.6667         9
#
#     accuracy                         0.5625        16
#    macro avg     0.5417    0.5317    0.5152        16
# weighted avg     0.5469    0.5625    0.5341        16
#
# Sensibilidade: 77.78
# Especificidade: 28.57
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 67.95
# CM :
#  [[2 1]
#  [4 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.3333    0.6667    0.4444         3
#          1.0     0.9000    0.6923    0.7826        13
#
#     accuracy                         0.6875        16
#    macro avg     0.6167    0.6795    0.6135        16
# weighted avg     0.7938    0.6875    0.7192        16
#
# Sensibilidade: 69.23
# Especificidade: 66.67
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 56.67
# CM :
#  [[2 4]
#  [2 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.3333    0.4000         6
#          1.0     0.6667    0.8000    0.7273        10
#
#     accuracy                         0.6250        16
#    macro avg     0.5833    0.5667    0.5636        16
# weighted avg     0.6042    0.6250    0.6045        16
#
# Sensibilidade: 80.00
# Especificidade: 33.33
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 60.71
# CM :
#  [[ 1  1]
#  [ 4 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.2000    0.5000    0.2857         2
#          1.0     0.9091    0.7143    0.8000        14
#
#     accuracy                         0.6875        16
#    macro avg     0.5545    0.6071    0.5429        16
# weighted avg     0.8205    0.6875    0.7357        16
#
# Sensibilidade: 71.43
# Especificidade: 50.00
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 73.33
# CM :
#  [[4 2]
#  [2 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.6667    0.6667         6
#          1.0     0.8000    0.8000    0.8000        10
#
#     accuracy                         0.7500        16
#    macro avg     0.7333    0.7333    0.7333        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# Sensibilidade: 80.00
# Especificidade: 66.67
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 56.36
# CM :
#  [[2 3]
#  [3 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.4000    0.4000    0.4000         5
#          1.0     0.7273    0.7273    0.7273        11
#
#     accuracy                         0.6250        16
#    macro avg     0.5636    0.5636    0.5636        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# Sensibilidade: 72.73
# Especificidade: 40.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 41.67
# CM :
#  [[ 0  4]
#  [ 2 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000         4
#          1.0     0.7143    0.8333    0.7692        12
#
#     accuracy                         0.6250        16
#    macro avg     0.3571    0.4167    0.3846        16
# weighted avg     0.5357    0.6250    0.5769        16
#
# Sensibilidade: 83.33
# Especificidade: 0.00
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 74.60
# CM :
#  [[5 2]
#  [2 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.7143    0.7143    0.7143         7
#          1.0     0.7778    0.7778    0.7778         9
#
#     accuracy                         0.7500        16
#    macro avg     0.7460    0.7460    0.7460        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# Sensibilidade: 77.78
# Especificidade: 71.43
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 63.33
# CM :
#  [[6 4]
#  [2 4]]
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.6000    0.6667        10
#          1.0     0.5000    0.6667    0.5714         6
#
#     accuracy                         0.6250        16
#    macro avg     0.6250    0.6333    0.6190        16
# weighted avg     0.6562    0.6250    0.6310        16
#
# Sensibilidade: 66.67
# Especificidade: 60.00
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 53.17
# CM :
#  [[2 5]
#  [2 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.2857    0.3636         7
#          1.0     0.5833    0.7778    0.6667         9
#
#     accuracy                         0.5625        16
#    macro avg     0.5417    0.5317    0.5152        16
# weighted avg     0.5469    0.5625    0.5341        16
#
# Sensibilidade: 77.78
# Especificidade: 28.57
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 68.75
# CM :
#  [[4 4]
#  [1 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.8000    0.5000    0.6154         8
#          1.0     0.6364    0.8750    0.7368         8
#
#     accuracy                         0.6875        16
#    macro avg     0.7182    0.6875    0.6761        16
# weighted avg     0.7182    0.6875    0.6761        16
#
# Sensibilidade: 87.50
# Especificidade: 50.00
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 67.46
# CM :
#  [[4 3]
#  [2 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.5714    0.6154         7
#          1.0     0.7000    0.7778    0.7368         9
#
#     accuracy                         0.6875        16
#    macro avg     0.6833    0.6746    0.6761        16
# weighted avg     0.6854    0.6875    0.6837        16
#
# Sensibilidade: 77.78
# Especificidade: 57.14
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 50.00
# CM :
#  [[1 3]
#  [3 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.2500    0.2500         4
#          1.0     0.7500    0.7500    0.7500        12
#
#     accuracy                         0.6250        16
#    macro avg     0.5000    0.5000    0.5000        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# Sensibilidade: 75.00
# Especificidade: 25.00
#
# Basic KNN Accuracy: 50.00
# Valor AUC-ROC : 50.00
# CM :
#  [[2 6]
#  [2 6]]
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.2500    0.3333         8
#          1.0     0.5000    0.7500    0.6000         8
#
#     accuracy                         0.5000        16
#    macro avg     0.5000    0.5000    0.4667        16
# weighted avg     0.5000    0.5000    0.4667        16
#
# Sensibilidade: 75.00
# Especificidade: 25.00
#
# Basic KNN Accuracy: 37.50
# Valor AUC-ROC : 37.50
# CM :
#  [[1 7]
#  [3 5]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.1250    0.1667         8
#          1.0     0.4167    0.6250    0.5000         8
#
#     accuracy                         0.3750        16
#    macro avg     0.3333    0.3750    0.3333        16
# weighted avg     0.3333    0.3750    0.3333        16
#
# Sensibilidade: 62.50
# Especificidade: 12.50
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 50.00
# CM :
#  [[1 3]
#  [3 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.2500    0.2500         4
#          1.0     0.7500    0.7500    0.7500        12
#
#     accuracy                         0.6250        16
#    macro avg     0.5000    0.5000    0.5000        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# Sensibilidade: 75.00
# Especificidade: 25.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 58.73
# CM :
#  [[2 5]
#  [1 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.2857    0.4000         7
#          1.0     0.6154    0.8889    0.7273         9
#
#     accuracy                         0.6250        16
#    macro avg     0.6410    0.5873    0.5636        16
# weighted avg     0.6378    0.6250    0.5841        16
#
# Sensibilidade: 88.89
# Especificidade: 28.57
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 61.67
# CM :
#  [[2 4]
#  [1 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.3333    0.4444         6
#          1.0     0.6923    0.9000    0.7826        10
#
#     accuracy                         0.6875        16
#    macro avg     0.6795    0.6167    0.6135        16
# weighted avg     0.6827    0.6875    0.6558        16
#
# Sensibilidade: 90.00
# Especificidade: 33.33
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 66.67
# CM :
#  [[ 2  2]
#  [ 2 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.5000    0.5000         4
#          1.0     0.8333    0.8333    0.8333        12
#
#     accuracy                         0.7500        16
#    macro avg     0.6667    0.6667    0.6667        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# Sensibilidade: 83.33
# Especificidade: 50.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 61.90
# CM :
#  [[4 3]
#  [3 6]]
#               precision    recall  f1-score   support
#
#          0.0     0.5714    0.5714    0.5714         7
#          1.0     0.6667    0.6667    0.6667         9
#
#     accuracy                         0.6250        16
#    macro avg     0.6190    0.6190    0.6190        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# Sensibilidade: 66.67
# Especificidade: 57.14
#
# Basic KNN Accuracy: 50.00
# Valor AUC-ROC : 46.03
# CM :
#  [[1 6]
#  [2 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.3333    0.1429    0.2000         7
#          1.0     0.5385    0.7778    0.6364         9
#
#     accuracy                         0.5000        16
#    macro avg     0.4359    0.4603    0.4182        16
# weighted avg     0.4487    0.5000    0.4455        16
#
# Sensibilidade: 77.78
# Especificidade: 14.29

# %% [markdown]
# ### Step 2 - Results with Standardization + KNN (step 1)

# %%
scaler=StandardScaler()
#scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[5.93261689e-01, 3.13673138e-01, 4.34043181e-01, ...,
#         6.35872024e-01, 7.93229052e-01, 6.66719844e-04],
#        [8.62519279e-02, 6.43120436e-03, 6.28812128e-01, ...,
#         4.11581649e-01, 4.31169592e-01, 3.69149497e-03],
#        [3.29403905e-01, 3.40954084e-01, 7.58122697e-01, ...,
#         7.98177643e-01, 7.82799692e-01, 6.49985887e-04],
#        ...,
#        [2.20823903e-01, 6.35155018e-02, 5.85174506e-01, ...,
#         5.36885532e-01, 5.33241543e-01, 5.37163427e-03],
#        [1.00785154e-01, 3.97801146e-02, 6.03675925e-01, ...,
#         4.62090853e-01, 5.70121989e-01, 2.52635150e-03],
#        [6.83777634e-02, 5.53951417e-03, 6.31066296e-01, ...,
#         0.00000000e+00, 6.96203530e-01, 1.08148060e-03]])

# %%
for i in range(1,31):
    X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.1, shuffle=True)
    knn = KNeighborsClassifier(n_neighbors = 1)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    acc = accuracy_score(y_test, y_pred)
    aucroc = roc_auc_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, digits=4)

    print("Basic KNN Accuracy: {:.2f}".format(acc*100))
    print("Valor AUC-ROC : {:.2f}".format(aucroc*100))
    print("CM : \n", cm)
    print(report)
    
    trueNegative=cm[0][0]
    falsePositive=cm[0][1]
    falsenegative=cm[1][0]
    truePositive=cm[1][1]
  
    print("Sensibilidade: {:.2f}".format((truePositive/(truePositive+falsenegative))*100))
    print("Especificidade: {:.2f}".format((trueNegative/(trueNegative+falsePositive))*100))
    print()
# Out:
# Basic KNN Accuracy: 50.00
# Valor AUC-ROC : 50.00
# CM :
#  [[3 3]
#  [5 5]]
#               precision    recall  f1-score   support
#
#          0.0     0.3750    0.5000    0.4286         6
#          1.0     0.6250    0.5000    0.5556        10
#
#     accuracy                         0.5000        16
#    macro avg     0.5000    0.5000    0.4921        16
# weighted avg     0.5312    0.5000    0.5079        16
#
# Sensibilidade: 50.00
# Especificidade: 50.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 62.50
# CM :
#  [[3 5]
#  [1 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.3750    0.5000         8
#          1.0     0.5833    0.8750    0.7000         8
#
#     accuracy                         0.6250        16
#    macro avg     0.6667    0.6250    0.6000        16
# weighted avg     0.6667    0.6250    0.6000        16
#
# Sensibilidade: 87.50
# Especificidade: 37.50
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 55.00
# CM :
#  [[3 3]
#  [4 6]]
#               precision    recall  f1-score   support
#
#          0.0     0.4286    0.5000    0.4615         6
#          1.0     0.6667    0.6000    0.6316        10
#
#     accuracy                         0.5625        16
#    macro avg     0.5476    0.5500    0.5466        16
# weighted avg     0.5774    0.5625    0.5678        16
#
# Sensibilidade: 60.00
# Especificidade: 50.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 65.08
# CM :
#  [[4 5]
#  [1 6]]
#               precision    recall  f1-score   support
#
#          0.0     0.8000    0.4444    0.5714         9
#          1.0     0.5455    0.8571    0.6667         7
#
#     accuracy                         0.6250        16
#    macro avg     0.6727    0.6508    0.6190        16
# weighted avg     0.6886    0.6250    0.6131        16
#
# Sensibilidade: 85.71
# Especificidade: 44.44
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 73.33
# CM :
#  [[4 2]
#  [2 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.6667    0.6667         6
#          1.0     0.8000    0.8000    0.8000        10
#
#     accuracy                         0.7500        16
#    macro avg     0.7333    0.7333    0.7333        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# Sensibilidade: 80.00
# Especificidade: 66.67
#
# Basic KNN Accuracy: 87.50
# Valor AUC-ROC : 83.33
# CM :
#  [[ 3  1]
#  [ 1 11]]
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.7500    0.7500         4
#          1.0     0.9167    0.9167    0.9167        12
#
#     accuracy                         0.8750        16
#    macro avg     0.8333    0.8333    0.8333        16
# weighted avg     0.8750    0.8750    0.8750        16
#
# Sensibilidade: 91.67
# Especificidade: 75.00
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 55.13
# CM :
#  [[ 1  2]
#  [ 3 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.3333    0.2857         3
#          1.0     0.8333    0.7692    0.8000        13
#
#     accuracy                         0.6875        16
#    macro avg     0.5417    0.5513    0.5429        16
# weighted avg     0.7240    0.6875    0.7036        16
#
# Sensibilidade: 76.92
# Especificidade: 33.33
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 85.71
# CM :
#  [[ 2  0]
#  [ 4 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.3333    1.0000    0.5000         2
#          1.0     1.0000    0.7143    0.8333        14
#
#     accuracy                         0.7500        16
#    macro avg     0.6667    0.8571    0.6667        16
# weighted avg     0.9167    0.7500    0.7917        16
#
# Sensibilidade: 71.43
# Especificidade: 100.00
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 61.67
# CM :
#  [[2 4]
#  [1 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.3333    0.4444         6
#          1.0     0.6923    0.9000    0.7826        10
#
#     accuracy                         0.6875        16
#    macro avg     0.6795    0.6167    0.6135        16
# weighted avg     0.6827    0.6875    0.6558        16
#
# Sensibilidade: 90.00
# Especificidade: 33.33
#
# Basic KNN Accuracy: 93.75
# Valor AUC-ROC : 92.86
# CM :
#  [[6 1]
#  [0 9]]
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8571    0.9231         7
#          1.0     0.9000    1.0000    0.9474         9
#
#     accuracy                         0.9375        16
#    macro avg     0.9500    0.9286    0.9352        16
# weighted avg     0.9437    0.9375    0.9367        16
#
# Sensibilidade: 100.00
# Especificidade: 85.71
#
# Basic KNN Accuracy: 81.25
# Valor AUC-ROC : 89.29
# CM :
#  [[ 2  0]
#  [ 3 11]]
#               precision    recall  f1-score   support
#
#          0.0     0.4000    1.0000    0.5714         2
#          1.0     1.0000    0.7857    0.8800        14
#
#     accuracy                         0.8125        16
#    macro avg     0.7000    0.8929    0.7257        16
# weighted avg     0.9250    0.8125    0.8414        16
#
# Sensibilidade: 78.57
# Especificidade: 100.00
#
# Basic KNN Accuracy: 81.25
# Valor AUC-ROC : 80.16
# CM :
#  [[5 2]
#  [1 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.8333    0.7143    0.7692         7
#          1.0     0.8000    0.8889    0.8421         9
#
#     accuracy                         0.8125        16
#    macro avg     0.8167    0.8016    0.8057        16
# weighted avg     0.8146    0.8125    0.8102        16
#
# Sensibilidade: 88.89
# Especificidade: 71.43
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 51.67
# CM :
#  [[2 4]
#  [3 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.4000    0.3333    0.3636         6
#          1.0     0.6364    0.7000    0.6667        10
#
#     accuracy                         0.5625        16
#    macro avg     0.5182    0.5167    0.5152        16
# weighted avg     0.5477    0.5625    0.5530        16
#
# Sensibilidade: 70.00
# Especificidade: 33.33
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 47.44
# CM :
#  [[1 2]
#  [5 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.1667    0.3333    0.2222         3
#          1.0     0.8000    0.6154    0.6957        13
#
#     accuracy                         0.5625        16
#    macro avg     0.4833    0.4744    0.4589        16
# weighted avg     0.6813    0.5625    0.6069        16
#
# Sensibilidade: 61.54
# Especificidade: 33.33
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 60.32
# CM :
#  [[3 4]
#  [2 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.6000    0.4286    0.5000         7
#          1.0     0.6364    0.7778    0.7000         9
#
#     accuracy                         0.6250        16
#    macro avg     0.6182    0.6032    0.6000        16
# weighted avg     0.6205    0.6250    0.6125        16
#
# Sensibilidade: 77.78
# Especificidade: 42.86
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 70.00
# CM :
#  [[3 3]
#  [1 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.5000    0.6000         6
#          1.0     0.7500    0.9000    0.8182        10
#
#     accuracy                         0.7500        16
#    macro avg     0.7500    0.7000    0.7091        16
# weighted avg     0.7500    0.7500    0.7364        16
#
# Sensibilidade: 90.00
# Especificidade: 50.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 58.73
# CM :
#  [[2 5]
#  [1 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.2857    0.4000         7
#          1.0     0.6154    0.8889    0.7273         9
#
#     accuracy                         0.6250        16
#    macro avg     0.6410    0.5873    0.5636        16
# weighted avg     0.6378    0.6250    0.5841        16
#
# Sensibilidade: 88.89
# Especificidade: 28.57
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 56.25
# CM :
#  [[3 5]
#  [2 6]]
#               precision    recall  f1-score   support
#
#          0.0     0.6000    0.3750    0.4615         8
#          1.0     0.5455    0.7500    0.6316         8
#
#     accuracy                         0.5625        16
#    macro avg     0.5727    0.5625    0.5466        16
# weighted avg     0.5727    0.5625    0.5466        16
#
# Sensibilidade: 75.00
# Especificidade: 37.50
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 55.45
# CM :
#  [[ 1  4]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.2000    0.2857         5
#          1.0     0.7143    0.9091    0.8000        11
#
#     accuracy                         0.6875        16
#    macro avg     0.6071    0.5545    0.5429        16
# weighted avg     0.6473    0.6875    0.6393        16
#
# Sensibilidade: 90.91
# Especificidade: 20.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 50.00
# CM :
#  [[1 3]
#  [3 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.2500    0.2500         4
#          1.0     0.7500    0.7500    0.7500        12
#
#     accuracy                         0.6250        16
#    macro avg     0.5000    0.5000    0.5000        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# Sensibilidade: 75.00
# Especificidade: 25.00
#
# Basic KNN Accuracy: 87.50
# Valor AUC-ROC : 80.00
# CM :
#  [[ 3  2]
#  [ 0 11]]
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.6000    0.7500         5
#          1.0     0.8462    1.0000    0.9167        11
#
#     accuracy                         0.8750        16
#    macro avg     0.9231    0.8000    0.8333        16
# weighted avg     0.8942    0.8750    0.8646        16
#
# Sensibilidade: 100.00
# Especificidade: 60.00
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 75.00
# CM :
#  [[3 1]
#  [3 9]]
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.7500    0.6000         4
#          1.0     0.9000    0.7500    0.8182        12
#
#     accuracy                         0.7500        16
#    macro avg     0.7000    0.7500    0.7091        16
# weighted avg     0.8000    0.7500    0.7636        16
#
# Sensibilidade: 75.00
# Especificidade: 75.00
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 65.00
# CM :
#  [[3 3]
#  [2 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.6000    0.5000    0.5455         6
#          1.0     0.7273    0.8000    0.7619        10
#
#     accuracy                         0.6875        16
#    macro avg     0.6636    0.6500    0.6537        16
# weighted avg     0.6795    0.6875    0.6807        16
#
# Sensibilidade: 80.00
# Especificidade: 50.00
#
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 76.67
# CM :
#  [[5 1]
#  [3 7]]
#               precision    recall  f1-score   support
#
#          0.0     0.6250    0.8333    0.7143         6
#          1.0     0.8750    0.7000    0.7778        10
#
#     accuracy                         0.7500        16
#    macro avg     0.7500    0.7667    0.7460        16
# weighted avg     0.7812    0.7500    0.7540        16
#
# Sensibilidade: 70.00
# Especificidade: 83.33
#
# Basic KNN Accuracy: 68.75
# Valor AUC-ROC : 55.13
# CM :
#  [[ 1  2]
#  [ 3 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.3333    0.2857         3
#          1.0     0.8333    0.7692    0.8000        13
#
#     accuracy                         0.6875        16
#    macro avg     0.5417    0.5513    0.5429        16
# weighted avg     0.7240    0.6875    0.7036        16
#
# Sensibilidade: 76.92
# Especificidade: 33.33
# Basic KNN Accuracy: 75.00
# Valor AUC-ROC : 65.45
# CM :
#  [[ 2  3]
#  [ 1 10]]
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.4000    0.5000         5
#          1.0     0.7692    0.9091    0.8333        11
#
#     accuracy                         0.7500        16
#    macro avg     0.7179    0.6545    0.6667        16
# weighted avg     0.7372    0.7500    0.7292        16
#
# Sensibilidade: 90.91
# Especificidade: 40.00
#
# Basic KNN Accuracy: 81.25
# Valor AUC-ROC : 80.16
# CM :
#  [[5 2]
#  [1 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.8333    0.7143    0.7692         7
#          1.0     0.8000    0.8889    0.8421         9
#
#     accuracy                         0.8125        16
#    macro avg     0.8167    0.8016    0.8057        16
# weighted avg     0.8146    0.8125    0.8102        16
#
# Sensibilidade: 88.89
# Especificidade: 71.43
#
# Basic KNN Accuracy: 56.25
# Valor AUC-ROC : 46.36
# CM :
#  [[1 4]
#  [3 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.2000    0.2222         5
#          1.0     0.6667    0.7273    0.6957        11
#
#     accuracy                         0.5625        16
#    macro avg     0.4583    0.4636    0.4589        16
# weighted avg     0.5365    0.5625    0.5477        16
#
# Sensibilidade: 72.73
# Especificidade: 20.00
#
# Basic KNN Accuracy: 81.25
# Valor AUC-ROC : 75.00
# CM :
#  [[ 3  3]
#  [ 0 10]]
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.5000    0.6667         6
#          1.0     0.7692    1.0000    0.8696        10
#
#     accuracy                         0.8125        16
#    macro avg     0.8846    0.7500    0.7681        16
# weighted avg     0.8558    0.8125    0.7935        16
#
# Sensibilidade: 100.00
# Especificidade: 50.00
#
# Basic KNN Accuracy: 62.50
# Valor AUC-ROC : 56.36
# CM :
#  [[2 3]
#  [3 8]]
#               precision    recall  f1-score   support
#
#          0.0     0.4000    0.4000    0.4000         5
#          1.0     0.7273    0.7273    0.7273        11
#
#     accuracy                         0.6250        16
#    macro avg     0.5636    0.5636    0.5636        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# Sensibilidade: 72.73
# Especificidade: 40.00

# %% [markdown]
# ### Step 3 - Results with Hiperparameters

# %%
def knn_best_params(X_train,X_test,y_train,y_test):
    k_range=list(range(1,31))
    weight_options=["uniform","distance"]
    print()
    
    param_grid=dict(n_neighbors=k_range,weights=weight_options)
    
    knn= KNeighborsClassifier()
    cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=10, random_state=42)
    grid=GridSearchCV(knn,param_grid,cv=cv,scoring="accuracy")
    grid.fit(X_train,y_train)
    
    print("Melhores parâmetros alcançados : ")
    print("Best acc. score: {}\n Best parameters {}".format(grid.best_score_,grid.best_params_))
    print()
    
    knn = KNeighborsClassifier(**grid.best_params_)
    knn.fit(X_train,y_train)
    
    y_pred_test= knn.predict(X_test)
    y_pred_train=knn.predict(X_train)
    
    cm_test=confusion_matrix(y_test,y_pred_test)
    cm_train=confusion_matrix(y_train,y_pred_train)
    
    acc_test= accuracy_score(y_test, y_pred_test)
    acc_train= accuracy_score(y_train, y_pred_train)
    
    aucroc_test = roc_auc_score(y_test, y_pred_test)
    aucroc_train = roc_auc_score(y_train, y_pred_train)
    
    report = classification_report(y_test, y_pred_test, digits=4)
    
    #print("Valor acuracia TRAIN :: {:.2f}".format(acc_train*100))
    #print("Matriz de confusão TRAIN\n",cm_train)
    #print("Valor AUC TRAIN :: {:.2f}".format(aucroc_train*100))
    #print()
    print("Valor acuracia TESTE :: {:.2f}".format(acc_test*100))
    print("Matriz de confusão TESTE\n",cm_test)
    print("Valor AUC TESTE :: {:.2f}".format(aucroc_test*100))
    print()
    print(report)
    
    trueNegative=cm_test[0][0]
    falsePositive=cm_test[0][1]
    falsenegative=cm_test[1][0]
    truePositive=cm_test[1][1]

    print("true negative", trueNegative)
    print("False Positive", falsePositive)
    print("false Negative", falsenegative)
    print("True Positive", truePositive)
    print()
    print("Sensibilidade: {:.2f}".format((truePositive/(truePositive+falsenegative))*100))
    print("Especificidade: {:.2f}".format((trueNegative/(trueNegative+falsePositive))*100))
    '''
    #roc curve
    RL_prob = knn.predict_proba(X_test)
    probs = RL_prob[:, 1]
    rfp, rvp, lim = metrics.roc_curve(y_test, probs)
    roc_auc = metrics.auc(rfp, rvp)
    #print('AUC: %f' % roc_auc)
    
    plt.title('Receiver Operating Characteristic Curve')
    plt.plot(rfp, rvp, marker='.', label = 'AUC = %0.2f' % roc_auc, color="orange")
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc = 'lower right')
    plt.show()
    
    #precision-recall curve
    plt.title('Precision-Recall Curve')
    knn_precision, knn_recall, _ = precision_recall_curve(y_test, probs)
    ap = average_precision_score(y_test, probs)
    baseline = len(y_test[y_test==1]) / len(y_test)
    plt.plot([0, 1], [baseline, baseline], linestyle='--')
    #plt.plot([1, 0], [0, 1], color='darkblue', linestyle='--')
    plt.plot(knn_recall, knn_precision, marker='.', label = 'AP = %0.2f' % ap, color="orange")
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend(loc = 'lower left')
    plt.show()
    ''' 
    return grid

# %%
resultados = []
for i in range(1,31):
    X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.1, shuffle=True)
    grid_nca = knn_best_params(X_train,X_test,y_train,y_test)
    resultados.append(grid_nca)
# Out:
# Melhores parâmetros alcançados :
# Best acc. score: 0.7363054187192118
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[3 3]
#  [1 9]]
# Valor AUC TESTE :: 70.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.5000    0.6000         6
#          1.0     0.7500    0.9000    0.8182        10
#
#     accuracy                         0.7500        16
#    macro avg     0.7500    0.7000    0.7091        16
# weighted avg     0.7500    0.7500    0.7364        16
#
# true negative 3
# False Positive 3
# false Negative 1
# True Positive 9
#
# Sensibilidade: 90.00
# Especificidade: 50.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7681034482758621
#  Best parameters {'n_neighbors': 6, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 62.50
# Matriz de confusão TESTE
#  [[1 3]
#  [3 9]]
# Valor AUC TESTE :: 50.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.2500    0.2500    0.2500         4
#          1.0     0.7500    0.7500    0.7500        12
#
#     accuracy                         0.6250        16
#    macro avg     0.5000    0.5000    0.5000        16
# weighted avg     0.6250    0.6250    0.6250        16
#
# true negative 1
# False Positive 3
# false Negative 3
# True Positive 9
#
# Sensibilidade: 75.00
# Especificidade: 25.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7433251231527092
#  Best parameters {'n_neighbors': 8, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 68.75
# Matriz de confusão TESTE
#  [[ 1  5]
#  [ 0 10]]
# Valor AUC TESTE :: 58.33
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.1667    0.2857         6
#          1.0     0.6667    1.0000    0.8000        10
#
#     accuracy                         0.6875        16
#    macro avg     0.8333    0.5833    0.5429        16
# weighted avg     0.7917    0.6875    0.6071        16
#
# true negative 1
# False Positive 5
# false Negative 0
# True Positive 10
#
# Sensibilidade: 100.00
# Especificidade: 16.67
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7711576354679802
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 62.50
# Matriz de confusão TESTE
#  [[3 5]
#  [1 7]]
# Valor AUC TESTE :: 62.50
#
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.3750    0.5000         8
#          1.0     0.5833    0.8750    0.7000         8
#
#     accuracy                         0.6250        16
#    macro avg     0.6667    0.6250    0.6000        16
# weighted avg     0.6667    0.6250    0.6000        16
#
# true negative 3
# False Positive 5
# false Negative 1
# True Positive 7
#
# Sensibilidade: 87.50
# Especificidade: 37.50
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7320935960591133
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[5 2]
#  [1 8]]
# Valor AUC TESTE :: 80.16
#
#               precision    recall  f1-score   support
#
#          0.0     0.8333    0.7143    0.7692         7
#          1.0     0.8000    0.8889    0.8421         9
#
#     accuracy                         0.8125        16
#    macro avg     0.8167    0.8016    0.8057        16
# weighted avg     0.8146    0.8125    0.8102        16
#
# true negative 5
# False Positive 2
# false Negative 1
# True Positive 8
#
# Sensibilidade: 88.89
# Especificidade: 71.43
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7560098522167487
#  Best parameters {'n_neighbors': 8, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[ 0  4]
#  [ 0 12]]
# Valor AUC TESTE :: 50.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000         4
#          1.0     0.7500    1.0000    0.8571        12
#
#     accuracy                         0.7500        16
#    macro avg     0.3750    0.5000    0.4286        16
# weighted avg     0.5625    0.7500    0.6429        16
#
# true negative 0
# False Positive 4
# false Negative 0
# True Positive 12
#
# Sensibilidade: 100.00
# Especificidade: 0.00
# C:\Users\Tony\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Tony\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Tony\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Melhores parâmetros alcançados :
# Best acc. score: 0.7642118226600985
#  Best parameters {'n_neighbors': 4, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 50.00
# Matriz de confusão TESTE
#  [[3 5]
#  [3 5]]
# Valor AUC TESTE :: 50.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.3750    0.4286         8
#          1.0     0.5000    0.6250    0.5556         8
#
#     accuracy                         0.5000        16
#    macro avg     0.5000    0.5000    0.4921        16
# weighted avg     0.5000    0.5000    0.4921        16
#
# true negative 3
# False Positive 5
# false Negative 3
# True Positive 5
#
# Sensibilidade: 62.50
# Especificidade: 37.50
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7467241379310344
#  Best parameters {'n_neighbors': 3, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[ 2  3]
#  [ 1 10]]
# Valor AUC TESTE :: 65.45
#
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.4000    0.5000         5
#          1.0     0.7692    0.9091    0.8333        11
#
#     accuracy                         0.7500        16
#    macro avg     0.7179    0.6545    0.6667        16
# weighted avg     0.7372    0.7500    0.7292        16
#
# true negative 2
# False Positive 3
# false Negative 1
# True Positive 10
#
# Sensibilidade: 90.91
# Especificidade: 40.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.75
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 56.25
# Matriz de confusão TESTE
#  [[2 7]
#  [0 7]]
# Valor AUC TESTE :: 61.11
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.2222    0.3636         9
#          1.0     0.5000    1.0000    0.6667         7
#
#     accuracy                         0.5625        16
#    macro avg     0.7500    0.6111    0.5152        16
# weighted avg     0.7812    0.5625    0.4962        16
#
# true negative 2
# False Positive 7
# false Negative 0
# True Positive 7
#
# Sensibilidade: 100.00
# Especificidade: 22.22
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7494581280788176
#  Best parameters {'n_neighbors': 11, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 68.75
# Matriz de confusão TESTE
#  [[ 1  5]
#  [ 0 10]]
# Valor AUC TESTE :: 58.33
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.1667    0.2857         6
#          1.0     0.6667    1.0000    0.8000        10
#
#     accuracy                         0.6875        16
#    macro avg     0.8333    0.5833    0.5429        16
# weighted avg     0.7917    0.6875    0.6071        16
#
# true negative 1
# False Positive 5
# false Negative 0
# True Positive 10
#
# Sensibilidade: 100.00
# Especificidade: 16.67
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7347044334975368
#  Best parameters {'n_neighbors': 9, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[ 1  2]
#  [ 1 12]]
# Valor AUC TESTE :: 62.82
#
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.3333    0.4000         3
#          1.0     0.8571    0.9231    0.8889        13
#
#     accuracy                         0.8125        16
#    macro avg     0.6786    0.6282    0.6444        16
# weighted avg     0.7902    0.8125    0.7972        16
#
# true negative 1
# False Positive 2
# false Negative 1
# True Positive 12
#
# Sensibilidade: 92.31
# Especificidade: 33.33
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7467733990147783
#  Best parameters {'n_neighbors': 11, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 68.75
# Matriz de confusão TESTE
#  [[ 1  5]
#  [ 0 10]]
# Valor AUC TESTE :: 58.33
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.1667    0.2857         6
#          1.0     0.6667    1.0000    0.8000        10
#
#     accuracy                         0.6875        16
#    macro avg     0.8333    0.5833    0.5429        16
# weighted avg     0.7917    0.6875    0.6071        16
#
# true negative 1
# False Positive 5
# false Negative 0
# True Positive 10
#
# Sensibilidade: 100.00
# Especificidade: 16.67
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7229064039408867
#  Best parameters {'n_neighbors': 12, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[ 3  2]
#  [ 1 10]]
# Valor AUC TESTE :: 75.45
#
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.6000    0.6667         5
#          1.0     0.8333    0.9091    0.8696        11
#
#     accuracy                         0.8125        16
#    macro avg     0.7917    0.7545    0.7681        16
# weighted avg     0.8073    0.8125    0.8062        16
#
# true negative 3
# False Positive 2
# false Negative 1
# True Positive 10
#
# Sensibilidade: 90.91
# Especificidade: 60.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7573891625615764
#  Best parameters {'n_neighbors': 8, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[3 4]
#  [0 9]]
# Valor AUC TESTE :: 71.43
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.4286    0.6000         7
#          1.0     0.6923    1.0000    0.8182         9
#
#     accuracy                         0.7500        16
#    macro avg     0.8462    0.7143    0.7091        16
# weighted avg     0.8269    0.7500    0.7227        16
#
# true negative 3
# False Positive 4
# false Negative 0
# True Positive 9
#
# Sensibilidade: 100.00
# Especificidade: 42.86
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.742192118226601
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[ 2  2]
#  [ 0 12]]
# Valor AUC TESTE :: 75.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.5000    0.6667         4
#          1.0     0.8571    1.0000    0.9231        12
#
#     accuracy                         0.8750        16
#    macro avg     0.9286    0.7500    0.7949        16
# weighted avg     0.8929    0.8750    0.8590        16
#
# true negative 2
# False Positive 2
# false Negative 0
# True Positive 12
#
# Sensibilidade: 100.00
# Especificidade: 50.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7467487684729065
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[ 2  1]
#  [ 2 11]]
# Valor AUC TESTE :: 75.64
#
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.6667    0.5714         3
#          1.0     0.9167    0.8462    0.8800        13
#
#     accuracy                         0.8125        16
#    macro avg     0.7083    0.7564    0.7257        16
# weighted avg     0.8385    0.8125    0.8221        16
#
# true negative 2
# False Positive 1
# false Negative 2
# True Positive 11
#
# Sensibilidade: 84.62
# Especificidade: 66.67
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7579556650246304
#  Best parameters {'n_neighbors': 8, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 62.50
# Matriz de confusão TESTE
#  [[ 0  6]
#  [ 0 10]]
# Valor AUC TESTE :: 50.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000         6
#          1.0     0.6250    1.0000    0.7692        10
#
#     accuracy                         0.6250        16
#    macro avg     0.3125    0.5000    0.3846        16
# weighted avg     0.3906    0.6250    0.4808        16
#
# true negative 0
# False Positive 6
# false Negative 0
# True Positive 10
#
# Sensibilidade: 100.00
# Especificidade: 0.00
# C:\Users\Tony\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Tony\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Tony\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Melhores parâmetros alcançados :
# Best acc. score: 0.7331280788177339
#  Best parameters {'n_neighbors': 19, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 68.75
# Matriz de confusão TESTE
#  [[ 1  4]
#  [ 1 10]]
# Valor AUC TESTE :: 55.45
#
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.2000    0.2857         5
#          1.0     0.7143    0.9091    0.8000        11
#
#     accuracy                         0.6875        16
#    macro avg     0.6071    0.5545    0.5429        16
# weighted avg     0.6473    0.6875    0.6393        16
#
# true negative 1
# False Positive 4
# false Negative 1
# True Positive 10
#
# Sensibilidade: 90.91
# Especificidade: 20.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7502955665024631
#  Best parameters {'n_neighbors': 9, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 56.25
# Matriz de confusão TESTE
#  [[1 6]
#  [1 8]]
# Valor AUC TESTE :: 51.59
#
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.1429    0.2222         7
#          1.0     0.5714    0.8889    0.6957         9
#
#     accuracy                         0.5625        16
#    macro avg     0.5357    0.5159    0.4589        16
# weighted avg     0.5402    0.5625    0.4885        16
#
# true negative 1
# False Positive 6
# false Negative 1
# True Positive 8
#
# Sensibilidade: 88.89
# Especificidade: 14.29
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7713793103448277
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[ 0  1]
#  [ 3 12]]
# Valor AUC TESTE :: 40.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000         1
#          1.0     0.9231    0.8000    0.8571        15
#
#     accuracy                         0.7500        16
#    macro avg     0.4615    0.4000    0.4286        16
# weighted avg     0.8654    0.7500    0.8036        16
#
# true negative 0
# False Positive 1
# false Negative 3
# True Positive 12
#
# Sensibilidade: 80.00
# Especificidade: 0.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7252955665024632
#  Best parameters {'n_neighbors': 10, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[ 2  2]
#  [ 2 10]]
# Valor AUC TESTE :: 66.67
#
#               precision    recall  f1-score   support
#
#          0.0     0.5000    0.5000    0.5000         4
#          1.0     0.8333    0.8333    0.8333        12
#
#     accuracy                         0.7500        16
#    macro avg     0.6667    0.6667    0.6667        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# true negative 2
# False Positive 2
# false Negative 2
# True Positive 10
#
# Sensibilidade: 83.33
# Especificidade: 50.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7362807881773399
#  Best parameters {'n_neighbors': 4, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 68.75
# Matriz de confusão TESTE
#  [[2 5]
#  [0 9]]
# Valor AUC TESTE :: 64.29
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.2857    0.4444         7
#          1.0     0.6429    1.0000    0.7826         9
#
#     accuracy                         0.6875        16
#    macro avg     0.8214    0.6429    0.6135        16
# weighted avg     0.7991    0.6875    0.6347        16
#
# true negative 2
# False Positive 5
# false Negative 0
# True Positive 9
#
# Sensibilidade: 100.00
# Especificidade: 28.57
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.731551724137931
#  Best parameters {'n_neighbors': 3, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[4 1]
#  [2 9]]
# Valor AUC TESTE :: 80.91
#
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.8000    0.7273         5
#          1.0     0.9000    0.8182    0.8571        11
#
#     accuracy                         0.8125        16
#    macro avg     0.7833    0.8091    0.7922        16
# weighted avg     0.8271    0.8125    0.8166        16
#
# true negative 4
# False Positive 1
# false Negative 2
# True Positive 9
#
# Sensibilidade: 81.82
# Especificidade: 80.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7606896551724138
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 62.50
# Matriz de confusão TESTE
#  [[2 5]
#  [1 8]]
# Valor AUC TESTE :: 58.73
#
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.2857    0.4000         7
#          1.0     0.6154    0.8889    0.7273         9
#
#     accuracy                         0.6250        16
#    macro avg     0.6410    0.5873    0.5636        16
# weighted avg     0.6378    0.6250    0.5841        16
#
# true negative 2
# False Positive 5
# false Negative 1
# True Positive 8
#
# Sensibilidade: 88.89
# Especificidade: 28.57
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7602955665024631
#  Best parameters {'n_neighbors': 3, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 50.00
# Matriz de confusão TESTE
#  [[3 6]
#  [2 5]]
# Valor AUC TESTE :: 52.38
#
#               precision    recall  f1-score   support
#
#          0.0     0.6000    0.3333    0.4286         9
#          1.0     0.4545    0.7143    0.5556         7
#
#     accuracy                         0.5000        16
#    macro avg     0.5273    0.5238    0.4921        16
# weighted avg     0.5364    0.5000    0.4841        16
#
# true negative 3
# False Positive 6
# false Negative 2
# True Positive 5
#
# Sensibilidade: 71.43
# Especificidade: 33.33
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7431773399014778
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[3 4]
#  [0 9]]
# Valor AUC TESTE :: 71.43
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.4286    0.6000         7
#          1.0     0.6923    1.0000    0.8182         9
#
#     accuracy                         0.7500        16
#    macro avg     0.8462    0.7143    0.7091        16
# weighted avg     0.8269    0.7500    0.7227        16
#
# true negative 3
# False Positive 4
# false Negative 0
# True Positive 9
#
# Sensibilidade: 100.00
# Especificidade: 42.86
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7546059113300493
#  Best parameters {'n_neighbors': 8, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 62.50
# Matriz de confusão TESTE
#  [[3 6]
#  [0 7]]
# Valor AUC TESTE :: 66.67
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.3333    0.5000         9
#          1.0     0.5385    1.0000    0.7000         7
#
#     accuracy                         0.6250        16
#    macro avg     0.7692    0.6667    0.6000        16
# weighted avg     0.7981    0.6250    0.5875        16
#
# true negative 3
# False Positive 6
# false Negative 0
# True Positive 7
#
# Sensibilidade: 100.00
# Especificidade: 33.33
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7145566502463054
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[ 2  1]
#  [ 0 13]]
# Valor AUC TESTE :: 83.33
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.6667    0.8000         3
#          1.0     0.9286    1.0000    0.9630        13
#
#     accuracy                         0.9375        16
#    macro avg     0.9643    0.8333    0.8815        16
# weighted avg     0.9420    0.9375    0.9324        16
#
# true negative 2
# False Positive 1
# false Negative 0
# True Positive 13
#
# Sensibilidade: 100.00
# Especificidade: 66.67
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7191871921182266
#  Best parameters {'n_neighbors': 5, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[ 2  2]
#  [ 1 11]]
# Valor AUC TESTE :: 70.83
#
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.5000    0.5714         4
#          1.0     0.8462    0.9167    0.8800        12
#
#     accuracy                         0.8125        16
#    macro avg     0.7564    0.7083    0.7257        16
# weighted avg     0.8013    0.8125    0.8029        16
#
# true negative 2
# False Positive 2
# false Negative 1
# True Positive 11
#
# Sensibilidade: 91.67
# Especificidade: 50.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.7232512315270937
#  Best parameters {'n_neighbors': 3, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[ 2  0]
#  [ 1 13]]
# Valor AUC TESTE :: 96.43
#
#               precision    recall  f1-score   support
#
#          0.0     0.6667    1.0000    0.8000         2
#          1.0     1.0000    0.9286    0.9630        14
#
#     accuracy                         0.9375        16
#    macro avg     0.8333    0.9643    0.8815        16
# weighted avg     0.9583    0.9375    0.9426        16
#
# true negative 2
# False Positive 0
# false Negative 1
# True Positive 13
#
# Sensibilidade: 92.86
# Especificidade: 100.00

# %% [markdown]
# ### Step 4 - Results with NCA + hiperparameters

# %%
#nca=NeighborhoodComponentsAnalysis(n_components=15,random_state=42)
#nca=NeighborhoodComponentsAnalysis(n_components=10,random_state=42)
nca=NeighborhoodComponentsAnalysis(n_components=8,random_state=42)
#nca=NeighborhoodComponentsAnalysis(n_components=6,random_state=42)
#nca=NeighborhoodComponentsAnalysis(n_components=4,random_state=42)
nca.fit(x_scaled,y)

x_reduced_nca = nca.transform(x_scaled)
#nca_data=pd.DataFrame(x_reduced_nca,columns=["p1","p2","p3","p4","p5","p6","p7","p8","p9","p10","p11","p12","p13","p14","p15"])
#nca_data=pd.DataFrame(x_reduced_nca,columns=["p1","p2","p3","p4","p5","p6","p7","p8","p9","p10"])
nca_data=pd.DataFrame(x_reduced_nca,columns=["f1","f2","f3","f4","f5","f6","f7","f8"])
#nca_data=pd.DataFrame(x_reduced_nca,columns=["p1","p2","p3","p4","p5","p6"])
#nca_data=pd.DataFrame(x_reduced_nca,columns=["f1","f2","f3","f4"])
nca_data["saidas"]=y

# %%
x_reduced_nca
# Out:
# array([[-1.33841567e+01,  2.31060786e+01,  2.32127968e+00,
#          4.51084288e+01],
#        [ 2.15168622e+00,  4.10094012e+00, -2.55200150e+01,
#          2.56264315e+01],
#        [-5.11547050e+00,  1.35637914e+01, -4.94956040e+01,
#          5.06122033e+01],
#        [ 9.40469794e+00,  1.16516545e+01, -3.20139885e+01,
#          3.48276412e+01],
#        [-5.93044202e+00,  1.03566171e+01, -3.61420931e+01,
#          3.86660036e+01],
#        [ 9.36207795e-01,  1.39949096e+01, -4.70726561e+01,
#          5.15742137e+01],
#        [ 1.07002134e+00,  1.72297070e+01,  2.54643640e+01,
#          1.84702995e+01],
#        [-4.21867478e+00,  4.42067120e+00, -2.03830537e+01,
#          3.17240792e+01],
#        [-1.22492947e+01, -4.40345266e-01,  7.24584451e+00,
#          3.45310979e+01],
#        [ 2.03887755e+00,  1.99345655e+01, -1.11618860e+01,
#          4.27478363e+01],
#        [-3.29094579e+00,  2.98423988e+00, -2.18339285e+01,
#          3.72335035e+01],
#        [ 9.18375428e+00,  2.24634755e+00, -3.36242695e+01,
#          2.65816101e+01],
#        [ 5.89033042e-01,  5.47886403e+00, -4.34280766e+01,
#          2.89814849e+01],
#        [-1.28378299e+00,  8.51293201e+00, -3.38460149e+01,
#          3.53884939e+01],
#        [-2.29379316e+00,  6.25682852e-01, -2.88879583e+01,
#          4.06292631e+01],
#        [ 4.41248393e+00,  1.70030421e+01, -1.67627564e+01,
#          5.29761235e+01],
#        [-5.38960182e+00,  2.74552104e+00, -2.02224007e+01,
#          2.88759445e+01],
#        [-7.26333287e+00,  8.27204573e+00, -3.68096283e+01,
#          4.28921648e+01],
#        [-1.91951581e+00, -9.42757782e-01, -2.62424806e+01,
#          4.04309372e+01],
#        [ 5.43049517e+00,  1.84279814e+01, -1.43303282e+01,
#          4.33398332e+01],
#        [-1.00640530e+01,  2.50254406e+00,  7.29660918e+00,
#          4.20994506e+01],
#        [ 7.16335300e-01,  6.32812961e+00, -3.41715779e+01,
#          3.77044503e+01],
#        [ 2.38700035e+00,  1.11826652e+01, -4.84931463e+01,
#          3.65359372e+01],
#        [ 5.08374162e-01,  1.82247406e+01,  9.03463558e+00,
#          2.31268183e+01],
#        [ 1.61675550e+01,  8.38764805e+00, -4.09517710e+01,
#          4.30897114e+01],
#        [-7.32371333e-01,  1.32375544e+01, -2.65824807e+01,
#          4.52140933e+01],
#        [-7.06994766e+00,  1.36923544e+01, -3.17019201e+01,
#          4.46927610e+01],
#        [ 1.14438498e+01,  3.61130403e+01,  1.75673336e+01,
#          4.19915425e+01],
#        [-5.21307886e+00,  4.86276128e+00, -4.01909745e+01,
#          3.84833769e+01],
#        [-2.29443399e+01,  1.30413519e+00,  5.67155222e+00,
#          3.32736531e+01],
#        [ 4.87854445e+00,  1.93324935e+01, -7.36327461e+00,
#          2.85317744e+01],
#        [-8.16076160e+00,  1.72748410e+01,  2.34728526e+00,
#          3.98913503e+01],
#        [ 9.17466210e+00,  4.38457794e-01, -5.86574503e+01,
#          4.08576502e+01],
#        [-3.51963111e+01,  1.45105256e+01,  4.21524170e+01,
#          4.24121086e+01],
#        [-1.14142121e+01,  1.92643459e+00,  1.37511681e+00,
#          3.04284299e+01],
#        [-6.34603940e+00,  6.48815645e+00, -4.72700775e+01,
#          4.35220945e+01],
#        [-2.31138183e+01,  3.95021675e+00,  8.75825105e-02,
#          3.70409764e+01],
#        [-1.57796939e+01, -5.57474120e+00,  4.52654608e+00,
#          3.65217646e+01],
#        [-3.21111455e+00,  3.25342085e+00, -2.84884713e+01,
#          3.39150882e+01],
#        [ 2.59438895e+00,  1.10800287e+01, -3.95773772e+01,
#          3.55969043e+01],
#        [-1.95620958e+00,  3.17030626e+01, -1.29019636e+01,
#          6.22353322e+01],
#        [ 2.24346882e+01,  9.89442130e+00, -4.55259352e+01,
#          3.58299140e+01],
#        [-1.15805936e+00,  3.51976505e+00, -3.59713210e+01,
#          2.51306481e+01],
#        [ 4.62657211e+00,  1.21026833e+01, -3.30498452e+01,
#          4.56207075e+01],
#        [ 1.19728516e+01,  9.92058312e+00, -4.52941689e+01,
#          4.28645576e+01],
#        [ 9.29880564e+00,  9.86897247e+00, -3.61355376e+01,
#          3.86838112e+01],
#        [-6.88080842e+00, -3.44768862e-01, -1.08825808e+01,
#          2.78369413e+01],
#        [ 7.86908333e+00,  6.28423138e+00, -3.68941740e+01,
#          3.32405887e+01],
#        [-1.65505476e+00,  5.60525154e+00, -4.49098099e+01,
#          3.26860941e+01],
#        [-1.86912473e+01,  2.04843028e+00,  9.33961520e-01,
#          3.40627951e+01],
#        [-5.96989479e+00,  2.96799159e+00, -3.00680950e+01,
#          3.11831562e+01],
#        [ 1.51666939e+01,  3.38406096e+01,  4.68537499e+01,
#          3.10895331e+01],
#        [-4.24305068e-02,  7.83430874e+00, -3.00212595e+01,
#          2.58485367e+01],
#        [-8.98638839e+00,  4.64545475e+00, -3.53257069e+01,
#          3.64600188e+01],
#        [-4.38385415e+00, -6.32576285e+00,  3.56523105e+01,
#          3.65086105e+01],
#        [-8.35979365e+00,  1.00641223e+01, -2.60767873e+01,
#          3.62023464e+01],
#        [ 8.91764040e+00,  1.07687169e+01, -5.75719316e+01,
#          4.18678772e+01],
#        [-1.79659422e+00,  1.76306081e+01, -2.55248827e+01,
#          4.35661354e+01],
#        [-9.01973712e+00, -1.53791435e-01, -2.74159315e+01,
#          3.80482277e+01],
#        [-3.18929853e+00,  4.90664010e+00, -3.90403268e+01,
#          4.39230544e+01],
#        [-2.04456404e+00,  1.01487733e+01, -3.74864846e+01,
#          3.54643970e+01],
#        [-4.03717573e+00,  2.24630448e+00,  1.41510769e+00,
#          2.41332367e+01],
#        [ 3.43934717e+01,  3.19536206e+01,  4.63624028e+01,
#          7.60073168e+00],
#        [ 8.58097831e-02,  1.18115839e+01, -5.28556910e+01,
#          4.46183892e+01],
#        [-5.47529991e+00,  2.06200877e+01,  2.60760581e+01,
#          2.89548960e+01],
#        [-7.00268303e+00,  3.05535151e+00, -1.04683712e+01,
#          3.37873528e+01],
#        [ 1.35553643e+00,  9.18953350e-01, -5.06522766e+01,
#          3.46579940e+01],
#        [-2.24657535e+01,  4.60548236e+00,  6.02248024e+01,
#          2.78114734e+01],
#        [ 2.43642172e+00,  1.69577711e+01,  2.98884388e+01,
#          2.38032590e+01],
#        [-1.67176251e+01,  5.19997587e+00, -6.59383255e+00,
#          3.48158932e+01],
#        [-5.52402475e+00,  1.51331278e+01, -2.95418452e+01,
#          4.11541469e+01],
#        [-1.08908423e+01,  4.98358423e+00,  1.92419534e+00,
#          3.31295886e+01],
#        [-2.17542183e+01, -5.09255382e+00,  1.78126690e+01,
#          3.97965913e+01],
#        [ 3.93833686e+00,  1.24290859e+01, -4.19636355e+01,
#          3.59868179e+01],
#        [ 9.52042623e-01,  2.26883043e+01,  1.43864223e+01,
#          4.49415265e+01],
#        [-4.50483416e+00,  4.94519929e+00, -3.57033519e+01,
#          4.75533204e+01],
#        [-1.61501154e+01,  4.83435154e+00,  3.11052711e-01,
#          3.08328530e+01],
#        [-7.94029452e-01,  2.47871131e+01, -1.51494129e+00,
#          4.35331194e+01],
#        [-1.70567128e+01,  4.75463989e+00, -2.59675316e+01,
#          2.76439197e+01],
#        [-2.00220970e+01,  2.12103735e+01, -5.03962543e+00,
#          5.35805421e+01],
#        [-1.52976819e+01,  5.88768987e+00,  3.03446584e+01,
#          3.54977382e+01],
#        [-1.26277887e+01,  8.23068844e+00, -1.48610755e+01,
#          3.05956338e+01],
#        [-1.23144746e+01,  9.37617801e+00, -3.94523997e+01,
#          4.49543311e+01],
#        [-2.39211849e-01,  3.18985714e+01, -7.38277825e+00,
#          6.14686591e+01],
#        [-1.87444312e+00,  3.49996078e+00, -2.56132853e+01,
#          3.53362987e+01],
#        [-1.68432766e+01,  1.26677602e+01, -2.62974195e+01,
#          4.34945305e+01],
#        [-1.38808808e+01,  1.62880968e+00, -4.21027457e+00,
#          2.88176516e+01],
#        [-5.62940079e+00,  8.21666662e+00, -1.81064292e+01,
#          3.18575162e+01],
#        [ 6.45744320e+00,  6.34797381e+01,  1.12747475e+02,
#          3.40867411e+01],
#        [-6.16832704e+00,  2.06343005e+01, -1.75878228e+01,
#          3.88598773e+01],
#        [-6.59336296e+00,  6.69406566e+00, -2.87062555e+01,
#          3.81083239e+01],
#        [-3.93295003e-01,  1.62357186e+01,  3.48423240e+01,
#          2.08074916e+01],
#        [-1.15025048e+01,  1.35208874e+01, -1.58419097e+01,
#          4.20367421e+01],
#        [ 6.24487229e+00,  1.37654836e+01, -1.43314098e+01,
#          4.30026599e+01],
#        [-2.60943548e+00,  1.24414607e+01, -3.41208536e+01,
#          3.96602974e+01],
#        [-6.10915282e+00,  1.76941739e+01, -9.36642969e+00,
#          3.69503451e+01],
#        [ 3.36987641e+01,  2.62905600e+01,  3.57746143e-01,
#          3.45646073e+01],
#        [-1.52776782e+01,  5.88729731e+00, -3.05876564e+00,
#          3.88549294e+01],
#        [-1.30027632e+01,  5.54172324e+00, -5.06015628e+00,
#          3.73986695e+01],
#        [-1.75355370e+01,  2.99300195e+00,  4.93943080e+00,
#          2.80155208e+01],
#        [ 8.21598541e+00,  9.48627846e+00, -3.94652903e+01,
#          3.43492355e+01],
#        [ 1.74229727e+01,  3.53137013e+01,  3.30306535e+01,
#          3.53664994e+01],
#        [ 5.12371387e-02,  3.72450882e+00, -2.92432290e+01,
#          3.83948543e+01],
#        [-7.34437894e+00,  1.65695869e+01, -1.45221407e+01,
#          3.73384856e+01],
#        [-7.30044804e+00,  1.32024871e+01, -3.49452743e+01,
#          4.33125126e+01],
#        [-1.53174898e+01,  9.59998765e+00, -5.73610136e+00,
#          2.91844996e+01],
#        [-1.28766986e+01, -5.76295490e-01,  1.35898548e+01,
#          3.06222932e+01],
#        [-7.17488402e+00,  1.28489420e+01, -1.31309916e+01,
#          4.65986079e+01],
#        [-3.24602082e+00, -2.99653833e+00, -2.40926087e+01,
#          3.55347240e+01],
#        [ 9.70886664e+00,  1.75041679e+01, -1.02610911e+01,
#          3.74678671e+01],
#        [-1.65826495e+00,  1.01653992e+01, -3.75190602e+01,
#          3.70717143e+01],
#        [-6.17980729e+00,  4.67980841e+00, -3.86338862e+01,
#          4.11387750e+01],
#        [ 9.90100599e+00,  1.05119007e+01, -3.34533040e+01,
#          3.22816760e+01],
#        [-1.87858801e+00,  6.73385581e+00, -3.57463274e+01,
#          3.28962450e+01],
#        [ 9.22680895e+00,  1.54319224e+01, -8.90718828e+00,
#          3.09013420e+01],
#        [-9.67346053e+00,  6.07878544e-01, -1.52376526e+01,
#          3.24889602e+01],
#        [ 1.13711688e+00,  1.34813807e+01, -2.86686544e+01,
#          3.79450944e+01],
#        [-2.48696825e+00,  3.11257625e+00, -3.89569626e+01,
#          3.73690220e+01],
#        [-6.86736550e+00,  7.00580107e+00, -3.29901293e+01,
#          4.55294314e+01],
#        [-7.98198054e+00,  3.30519014e-01, -1.67899785e+01,
#          2.58531391e+01],
#        [ 1.21989703e+00,  9.53109162e+00, -3.43205028e+01,
#          2.91603044e+01],
#        [ 8.72749404e+00,  1.75553184e+01, -2.42472111e+01,
#          3.52752060e+01],
#        [ 1.26738704e+00,  1.47320266e+01, -3.42368590e+00,
#          2.53439915e+01],
#        [ 1.08137516e+01,  7.16198720e+00, -6.09235216e+01,
#          3.32670983e+01],
#        [-6.48771271e-01,  9.98835556e+00, -2.45059962e+01,
#          4.42471496e+01],
#        [-5.28239028e+00,  1.27517205e+01,  1.20001024e+01,
#          3.70590545e+01],
#        [ 3.92001987e-02,  1.07364310e+01, -1.69355361e+01,
#          3.20809806e+01],
#        [-6.39282496e+00,  4.65574131e+00, -1.42180552e+01,
#          3.17882363e+01],
#        [-2.39182426e+01,  2.57863086e+00,  3.78967951e+01,
#          2.12834504e+01],
#        [-6.12458542e+00, -3.55542160e+00, -1.78137271e+00,
#          3.14976443e+01],
#        [-1.57277039e+01,  4.42207363e+00,  4.68289556e-01,
#          2.61360918e+01],
#        [-7.16347503e+00,  2.57933467e+00, -2.39934629e+01,
#          2.39731180e+01],
#        [ 4.38164801e+00,  5.90278713e+00, -5.98586753e+01,
#          3.90689497e+01],
#        [ 7.09907650e+00,  5.16834371e+00, -4.19046212e+01,
#          2.64608999e+01],
#        [-7.99834801e+00,  1.20642516e+01, -1.90759211e+01,
#          3.97418376e+01],
#        [-1.51288295e+00,  4.74363984e+00, -1.98006279e+01,
#          3.05353307e+01],
#        [ 9.57988697e+00,  1.08333136e+01, -2.24125166e+01,
#          3.28520029e+01],
#        [ 9.76037105e+00,  1.04551111e+01, -2.92672691e+01,
#          4.01914966e+01],
#        [ 1.96494898e+01,  5.24646771e+00, -6.83719347e+01,
#          4.72508376e+01],
#        [ 2.21310496e+00,  1.27697535e+01, -2.91892845e+01,
#          4.48647509e+01],
#        [-1.28670518e+01, -1.37806521e+00,  1.17319501e+00,
#          2.83483541e+01],
#        [-6.01037838e+00,  4.70449682e+00, -1.75262808e+01,
#          2.88853349e+01],
#        [-1.00944180e+01,  1.78680563e+00, -3.71773981e+00,
#          3.48667079e+01],
#        [-1.63514511e+01,  6.37653703e+00, -6.33698259e+00,
#          3.02939293e+01],
#        [ 1.86889945e+01,  1.56894107e+01, -3.33081390e+01,
#          3.71961464e+01],
#        [ 4.34911142e+00,  5.41979074e+00, -4.59954391e+01,
#          3.18971732e+01],
#        [-1.61714765e+01, -7.28600205e-01,  4.32027710e+00,
#          3.15967510e+01],
#        [-9.54641444e+00,  6.40182328e+00, -2.59470223e+00,
#          3.14686305e+01],
#        [ 2.11121939e+00,  3.28038683e+01, -1.29892118e+01,
#          6.77255541e+01],
#        [-3.71388937e+00,  1.43328188e+00,  1.22400721e+00,
#          3.64890414e+01],
#        [ 2.15168622e+00,  4.10094012e+00, -2.55200150e+01,
#          2.56264315e+01],
#        [-1.63514511e+01,  6.37653703e+00, -6.33698259e+00,
#          3.02939293e+01],
#        [-1.51288295e+00,  4.74363984e+00, -1.98006279e+01,
#          3.05353307e+01],
#        [-1.00944180e+01,  1.78680563e+00, -3.71773981e+00,
#          3.48667079e+01],
#        [ 1.08137516e+01,  7.16198720e+00, -6.09235216e+01,
#          3.32670983e+01],
#        [-1.68432766e+01,  1.26677602e+01, -2.62974195e+01,
#          4.34945305e+01],
#        [ 3.92001987e-02,  1.07364310e+01, -1.69355361e+01,
#          3.20809806e+01],
#        [-6.39282496e+00,  4.65574131e+00, -1.42180552e+01,
#          3.17882363e+01],
#        [-2.39182426e+01,  2.57863086e+00,  3.78967951e+01,
#          2.12834504e+01]])

# %%
resultados_NCA = []
for i in range(1,31):
    X_train_nca, X_test_nca, y_train_nca, y_test_nca = train_test_split(x_reduced_nca, y, test_size=0.1, shuffle=True)
    grid_nca = knn_best_params(X_train_nca,X_test_nca,y_train_nca,y_test_nca)
    resultados_NCA.append(grid_nca)
# Out:
# Melhores parâmetros alcançados :
# Best acc. score: 0.8623152709359606
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[ 2  1]
#  [ 0 13]]
# Valor AUC TESTE :: 83.33
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.6667    0.8000         3
#          1.0     0.9286    1.0000    0.9630        13
#
#     accuracy                         0.9375        16
#    macro avg     0.9643    0.8333    0.8815        16
# weighted avg     0.9420    0.9375    0.9324        16
#
# true negative 2
# False Positive 1
# false Negative 0
# True Positive 13
#
# Sensibilidade: 100.00
# Especificidade: 66.67
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8685221674876847
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[6 0]
#  [1 9]]
# Valor AUC TESTE :: 95.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.8571    1.0000    0.9231         6
#          1.0     1.0000    0.9000    0.9474        10
#
#     accuracy                         0.9375        16
#    macro avg     0.9286    0.9500    0.9352        16
# weighted avg     0.9464    0.9375    0.9383        16
#
# true negative 6
# False Positive 0
# false Negative 1
# True Positive 9
#
# Sensibilidade: 90.00
# Especificidade: 100.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8820197044334976
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[ 4  1]
#  [ 0 11]]
# Valor AUC TESTE :: 90.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8000    0.8889         5
#          1.0     0.9167    1.0000    0.9565        11
#
#     accuracy                         0.9375        16
#    macro avg     0.9583    0.9000    0.9227        16
# weighted avg     0.9427    0.9375    0.9354        16
#
# true negative 4
# False Positive 1
# false Negative 0
# True Positive 11
#
# Sensibilidade: 100.00
# Especificidade: 80.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.858374384236453
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[6 1]
#  [0 9]]
# Valor AUC TESTE :: 92.86
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8571    0.9231         7
#          1.0     0.9000    1.0000    0.9474         9
#
#     accuracy                         0.9375        16
#    macro avg     0.9500    0.9286    0.9352        16
# weighted avg     0.9437    0.9375    0.9367        16
#
# true negative 6
# False Positive 1
# false Negative 0
# True Positive 9
#
# Sensibilidade: 100.00
# Especificidade: 85.71
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8904433497536947
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[ 2  1]
#  [ 1 12]]
# Valor AUC TESTE :: 79.49
#
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.6667    0.6667         3
#          1.0     0.9231    0.9231    0.9231        13
#
#     accuracy                         0.8750        16
#    macro avg     0.7949    0.7949    0.7949        16
# weighted avg     0.8750    0.8750    0.8750        16
#
# true negative 2
# False Positive 1
# false Negative 1
# True Positive 12
#
# Sensibilidade: 92.31
# Especificidade: 66.67
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8512315270935962
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[6 1]
#  [1 8]]
# Valor AUC TESTE :: 87.30
#
#               precision    recall  f1-score   support
#
#          0.0     0.8571    0.8571    0.8571         7
#          1.0     0.8889    0.8889    0.8889         9
#
#     accuracy                         0.8750        16
#    macro avg     0.8730    0.8730    0.8730        16
# weighted avg     0.8750    0.8750    0.8750        16
#
# true negative 6
# False Positive 1
# false Negative 1
# True Positive 8
#
# Sensibilidade: 88.89
# Especificidade: 85.71
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8503201970443349
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[ 5  1]
#  [ 0 10]]
# Valor AUC TESTE :: 91.67
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8333    0.9091         6
#          1.0     0.9091    1.0000    0.9524        10
#
#     accuracy                         0.9375        16
#    macro avg     0.9545    0.9167    0.9307        16
# weighted avg     0.9432    0.9375    0.9361        16
#
# true negative 5
# False Positive 1
# false Negative 0
# True Positive 10
#
# Sensibilidade: 100.00
# Especificidade: 83.33
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8721428571428572
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 100.00
# Matriz de confusão TESTE
#  [[7 0]
#  [0 9]]
# Valor AUC TESTE :: 100.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000         7
#          1.0     1.0000    1.0000    1.0000         9
#
#     accuracy                         1.0000        16
#    macro avg     1.0000    1.0000    1.0000        16
# weighted avg     1.0000    1.0000    1.0000        16
#
# true negative 7
# False Positive 0
# false Negative 0
# True Positive 9
#
# Sensibilidade: 100.00
# Especificidade: 100.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8585714285714287
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[9 1]
#  [0 6]]
# Valor AUC TESTE :: 95.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.9000    0.9474        10
#          1.0     0.8571    1.0000    0.9231         6
#
#     accuracy                         0.9375        16
#    macro avg     0.9286    0.9500    0.9352        16
# weighted avg     0.9464    0.9375    0.9383        16
#
# true negative 9
# False Positive 1
# false Negative 0
# True Positive 6
#
# Sensibilidade: 100.00
# Especificidade: 90.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8545320197044336
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 100.00
# Matriz de confusão TESTE
#  [[ 3  0]
#  [ 0 13]]
# Valor AUC TESTE :: 100.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000         3
#          1.0     1.0000    1.0000    1.0000        13
#
#     accuracy                         1.0000        16
#    macro avg     1.0000    1.0000    1.0000        16
# weighted avg     1.0000    1.0000    1.0000        16
#
# true negative 3
# False Positive 0
# false Negative 0
# True Positive 13
#
# Sensibilidade: 100.00
# Especificidade: 100.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8421674876847292
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 100.00
# Matriz de confusão TESTE
#  [[8 0]
#  [0 8]]
# Valor AUC TESTE :: 100.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000         8
#          1.0     1.0000    1.0000    1.0000         8
#
#     accuracy                         1.0000        16
#    macro avg     1.0000    1.0000    1.0000        16
# weighted avg     1.0000    1.0000    1.0000        16
#
# true negative 8
# False Positive 0
# false Negative 0
# True Positive 8
#
# Sensibilidade: 100.00
# Especificidade: 100.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8532512315270935
#  Best parameters {'n_neighbors': 8, 'weights': 'distance'}
#
# Valor acuracia TESTE :: 75.00
# Matriz de confusão TESTE
#  [[6 2]
#  [2 6]]
# Valor AUC TESTE :: 75.00
#
#               precision    recall  f1-score   support
#
#          0.0     0.7500    0.7500    0.7500         8
#          1.0     0.7500    0.7500    0.7500         8
#
#     accuracy                         0.7500        16
#    macro avg     0.7500    0.7500    0.7500        16
# weighted avg     0.7500    0.7500    0.7500        16
#
# true negative 6
# False Positive 2
# false Negative 2
# True Positive 6
#
# Sensibilidade: 75.00
# Especificidade: 75.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8457142857142856
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 100.00
# Matriz de confusão TESTE
#  [[ 6  0]
#  [ 0 10]]
# Valor AUC TESTE :: 100.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000         6
#          1.0     1.0000    1.0000    1.0000        10
#
#     accuracy                         1.0000        16
#    macro avg     1.0000    1.0000    1.0000        16
# weighted avg     1.0000    1.0000    1.0000        16
#
# true negative 6
# False Positive 0
# false Negative 0
# True Positive 10
#
# Sensibilidade: 100.00
# Especificidade: 100.00
# Melhores parâmetros alcançados :
# Best acc. score: 0.8473645320197045
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[8 1]
#  [0 7]]
# Valor AUC TESTE :: 94.44
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8889    0.9412         9
#          1.0     0.8750    1.0000    0.9333         7
#
#     accuracy                         0.9375        16
#    macro avg     0.9375    0.9444    0.9373        16
# weighted avg     0.9453    0.9375    0.9377        16
#
# true negative 8
# False Positive 1
# false Negative 0
# True Positive 7
#
# Sensibilidade: 100.00
# Especificidade: 88.89
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8525862068965517
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[6 1]
#  [0 9]]
# Valor AUC TESTE :: 92.86
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8571    0.9231         7
#          1.0     0.9000    1.0000    0.9474         9
#
#     accuracy                         0.9375        16
#    macro avg     0.9500    0.9286    0.9352        16
# weighted avg     0.9437    0.9375    0.9367        16
#
# true negative 6
# False Positive 1
# false Negative 0
# True Positive 9
#
# Sensibilidade: 100.00
# Especificidade: 85.71
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.874384236453202
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[ 2  2]
#  [ 0 12]]
# Valor AUC TESTE :: 75.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.5000    0.6667         4
#          1.0     0.8571    1.0000    0.9231        12
#
#     accuracy                         0.8750        16
#    macro avg     0.9286    0.7500    0.7949        16
# weighted avg     0.8929    0.8750    0.8590        16
#
# true negative 2
# False Positive 2
# false Negative 0
# True Positive 12
#
# Sensibilidade: 100.00
# Especificidade: 50.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.880960591133005
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[6 1]
#  [1 8]]
# Valor AUC TESTE :: 87.30
#
#               precision    recall  f1-score   support
#
#          0.0     0.8571    0.8571    0.8571         7
#          1.0     0.8889    0.8889    0.8889         9
#
#     accuracy                         0.8750        16
#    macro avg     0.8730    0.8730    0.8730        16
# weighted avg     0.8750    0.8750    0.8750        16
#
# true negative 6
# False Positive 1
# false Negative 1
# True Positive 8
#
# Sensibilidade: 88.89
# Especificidade: 85.71
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8727586206896554
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[6 1]
#  [0 9]]
# Valor AUC TESTE :: 92.86
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8571    0.9231         7
#          1.0     0.9000    1.0000    0.9474         9
#
#     accuracy                         0.9375        16
#    macro avg     0.9500    0.9286    0.9352        16
# weighted avg     0.9437    0.9375    0.9367        16
#
# true negative 6
# False Positive 1
# false Negative 0
# True Positive 9
#
# Sensibilidade: 100.00
# Especificidade: 85.71
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8634482758620688
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[4 1]
#  [2 9]]
# Valor AUC TESTE :: 80.91
#
#               precision    recall  f1-score   support
#
#          0.0     0.6667    0.8000    0.7273         5
#          1.0     0.9000    0.8182    0.8571        11
#
#     accuracy                         0.8125        16
#    macro avg     0.7833    0.8091    0.7922        16
# weighted avg     0.8271    0.8125    0.8166        16
#
# true negative 4
# False Positive 1
# false Negative 2
# True Positive 9
#
# Sensibilidade: 81.82
# Especificidade: 80.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8545320197044336
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 100.00
# Matriz de confusão TESTE
#  [[ 5  0]
#  [ 0 11]]
# Valor AUC TESTE :: 100.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000         5
#          1.0     1.0000    1.0000    1.0000        11
#
#     accuracy                         1.0000        16
#    macro avg     1.0000    1.0000    1.0000        16
# weighted avg     1.0000    1.0000    1.0000        16
#
# true negative 5
# False Positive 0
# false Negative 0
# True Positive 11
#
# Sensibilidade: 100.00
# Especificidade: 100.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8517487684729065
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 100.00
# Matriz de confusão TESTE
#  [[ 4  0]
#  [ 0 12]]
# Valor AUC TESTE :: 100.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000         4
#          1.0     1.0000    1.0000    1.0000        12
#
#     accuracy                         1.0000        16
#    macro avg     1.0000    1.0000    1.0000        16
# weighted avg     1.0000    1.0000    1.0000        16
#
# true negative 4
# False Positive 0
# false Negative 0
# True Positive 12
#
# Sensibilidade: 100.00
# Especificidade: 100.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8923891625615764
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[ 3  2]
#  [ 0 11]]
# Valor AUC TESTE :: 80.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.6000    0.7500         5
#          1.0     0.8462    1.0000    0.9167        11
#
#     accuracy                         0.8750        16
#    macro avg     0.9231    0.8000    0.8333        16
# weighted avg     0.8942    0.8750    0.8646        16
#
# true negative 3
# False Positive 2
# false Negative 0
# True Positive 11
#
# Sensibilidade: 100.00
# Especificidade: 60.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.877536945812808
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[7 1]
#  [1 7]]
# Valor AUC TESTE :: 87.50
#
#               precision    recall  f1-score   support
#
#          0.0     0.8750    0.8750    0.8750         8
#          1.0     0.8750    0.8750    0.8750         8
#
#     accuracy                         0.8750        16
#    macro avg     0.8750    0.8750    0.8750        16
# weighted avg     0.8750    0.8750    0.8750        16
#
# true negative 7
# False Positive 1
# false Negative 1
# True Positive 7
#
# Sensibilidade: 87.50
# Especificidade: 87.50
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8601477832512314
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 100.00
# Matriz de confusão TESTE
#  [[ 5  0]
#  [ 0 11]]
# Valor AUC TESTE :: 100.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000         5
#          1.0     1.0000    1.0000    1.0000        11
#
#     accuracy                         1.0000        16
#    macro avg     1.0000    1.0000    1.0000        16
# weighted avg     1.0000    1.0000    1.0000        16
#
# true negative 5
# False Positive 0
# false Negative 0
# True Positive 11
#
# Sensibilidade: 100.00
# Especificidade: 100.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8706896551724138
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[5 1]
#  [1 9]]
# Valor AUC TESTE :: 86.67
#
#               precision    recall  f1-score   support
#
#          0.0     0.8333    0.8333    0.8333         6
#          1.0     0.9000    0.9000    0.9000        10
#
#     accuracy                         0.8750        16
#    macro avg     0.8667    0.8667    0.8667        16
# weighted avg     0.8750    0.8750    0.8750        16
#
# true negative 5
# False Positive 1
# false Negative 1
# True Positive 9
#
# Sensibilidade: 90.00
# Especificidade: 83.33
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8708374384236452
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[ 5  1]
#  [ 0 10]]
# Valor AUC TESTE :: 91.67
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8333    0.9091         6
#          1.0     0.9091    1.0000    0.9524        10
#
#     accuracy                         0.9375        16
#    macro avg     0.9545    0.9167    0.9307        16
# weighted avg     0.9432    0.9375    0.9361        16
#
# true negative 5
# False Positive 1
# false Negative 0
# True Positive 10
#
# Sensibilidade: 100.00
# Especificidade: 83.33
# Melhores parâmetros alcançados :
# Best acc. score: 0.8645320197044335
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[7 1]
#  [0 8]]
# Valor AUC TESTE :: 93.75
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8750    0.9333         8
#          1.0     0.8889    1.0000    0.9412         8
#
#     accuracy                         0.9375        16
#    macro avg     0.9444    0.9375    0.9373        16
# weighted avg     0.9444    0.9375    0.9373        16
#
# true negative 7
# False Positive 1
# false Negative 0
# True Positive 8
#
# Sensibilidade: 100.00
# Especificidade: 87.50
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.870665024630542
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 87.50
# Matriz de confusão TESTE
#  [[ 3  2]
#  [ 0 11]]
# Valor AUC TESTE :: 80.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.6000    0.7500         5
#          1.0     0.8462    1.0000    0.9167        11
#
#     accuracy                         0.8750        16
#    macro avg     0.9231    0.8000    0.8333        16
# weighted avg     0.8942    0.8750    0.8646        16
#
# true negative 3
# False Positive 2
# false Negative 0
# True Positive 11
#
# Sensibilidade: 100.00
# Especificidade: 60.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8672660098522169
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 93.75
# Matriz de confusão TESTE
#  [[ 4  1]
#  [ 0 11]]
# Valor AUC TESTE :: 90.00
#
#               precision    recall  f1-score   support
#
#          0.0     1.0000    0.8000    0.8889         5
#          1.0     0.9167    1.0000    0.9565        11
#
#     accuracy                         0.9375        16
#    macro avg     0.9583    0.9000    0.9227        16
# weighted avg     0.9427    0.9375    0.9354        16
#
# true negative 4
# False Positive 1
# false Negative 0
# True Positive 11
#
# Sensibilidade: 100.00
# Especificidade: 80.00
#
# Melhores parâmetros alcançados :
# Best acc. score: 0.8789162561576355
#  Best parameters {'n_neighbors': 1, 'weights': 'uniform'}
#
# Valor acuracia TESTE :: 81.25
# Matriz de confusão TESTE
#  [[4 0]
#  [3 9]]
# Valor AUC TESTE :: 87.50
#
#               precision    recall  f1-score   support
#
#          0.0     0.5714    1.0000    0.7273         4
#          1.0     1.0000    0.7500    0.8571        12
#
#     accuracy                         0.8125        16
#    macro avg     0.7857    0.8750    0.7922        16
# weighted avg     0.8929    0.8125    0.8247        16
#
# true negative 4
# False Positive 0
# false Negative 3
# True Positive 9
#
# Sensibilidade: 75.00
# Especificidade: 100.00
